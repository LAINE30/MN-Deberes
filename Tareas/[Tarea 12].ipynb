# %% [markdown]
# # Escuela Politécnica Nacional
# ### [Tarea 09] Ejercicios Unidad 04-A-B | Eliminación gaussiana vs Gauss-Jordan
# **Nombre:** Mateo Coronado
#
# **Fecha:** 03/01/2025
#
# **Materia:** Métodos Numéricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import numpy as np
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana2
from src import eliminacion_gaussiana3
from src import eliminacion_gauss_jordan

# %%
print("Ejercicio a \n")
Ab = [[1, 2, 0], [1, -1, 0]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio a
#
# [01-10 11:17:12][INFO]
# [[ 1  2  0]
#  [ 0 -3  0]]
# array([ 0., -0.])

# %%
print("Ejercicio b \n")
Ab = [[1, 2, 3], [-2, -4, 6]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio b
#
# [01-10 11:17:12][INFO]
# [[ 1  2  3]
#  [ 0  0 12]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 print("Ejercicio b \n")
#       2 Ab = [[1, 2, 3], [-2, -4, 6]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:82, in eliminacion_gaussiana(A)
#      79     logging.info(f"\n{A}")
#      81 if A[n - 1, n - 1] == 0:
# ---> 82     raise ValueError("No existe solución única.")
#      84     print(f"\n{A}")
#      85 # --- Sustitución hacia atrás
#
# ValueError: No existe solución única.

# %% [markdown]
# El ejercicio b tiene la ecuacion de la forma 0=12 por lo cual no tiene solución

# %%
print("Ejercicio c \n")
Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio c
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 print("Ejercicio c \n")
#       2 Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:43, in eliminacion_gaussiana(A)
#      41     logging.debug("Convirtiendo A a numpy array.")
#      42     A = np.array(A)
# ---> 43 assert A.shape[0] == A.shape[1] - 1, "La matriz A debe ser de tamaño n-by-(n+1)."
#      44 n = A.shape[0]
#      46 for i in range(0, n - 1):  # loop por columna
#      47
#      48     # --- encontrar pivote
#
# AssertionError: La matriz A debe ser de tamaño n-by-(n+1).

# %% [markdown]
# Tiene soluciones infinitas

# %%
print("Ejercicio d \n")
Ab = [[2, 1, 1, 1], [2, 4, -1, -1]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio d
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 print("Ejercicio d \n")
#       2 Ab = [[2, 1, 1, 1], [2, 4, -1, -1]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:43, in eliminacion_gaussiana(A)
#      41     logging.debug("Convirtiendo A a numpy array.")
#      42     A = np.array(A)
# ---> 43 assert A.shape[0] == A.shape[1] - 1, "La matriz A debe ser de tamaño n-by-(n+1)."
#      44 n = A.shape[0]
#      46 for i in range(0, n - 1):  # loop por columna
#      47
#      48     # --- encontrar pivote
#
# AssertionError: La matriz A debe ser de tamaño n-by-(n+1).

# %% [markdown]
# Tiene soluciones infinitas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ejercicio a \n")
Ab = [[-1.0, 4, 1, 8], [5/3, 2/3, -2/3, 1.0], [2, 1, 4, 11.0]]
Ab = [[round(elem, 2) for elem in row] for row in Ab]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio a
#
# [01-07 20:29:44][INFO]
# [[-1.    4.    1.    8.  ]
#  [ 0.    7.35  1.   14.36]
#  [ 0.    9.    6.   27.  ]]
# [01-07 20:29:44][INFO]
# [[-1.          4.          1.          8.        ]
#  [ 0.          7.35        1.         14.36      ]
#  [ 0.          0.          4.7755102   9.41632653]]
# array([0.71367521, 1.68547009, 1.97179487])

# %%
print("Ejercicio b \n")
Ab = [[4, 2, -1, -5], [1/9, 1/9, -1/3, -1.0], [1, 4, 2, 9]]


eliminacion_gaussiana(Ab)
# Out:
# Ejercicio b
#
# [01-07 20:29:14][INFO]
# [[ 0.11111111  0.11111111 -0.33333333 -1.        ]
#  [ 0.         -2.         11.         31.        ]
#  [ 0.          3.          5.         18.        ]]
# [01-07 20:29:14][INFO]
# [[ 0.11111111  0.11111111 -0.33333333 -1.        ]
#  [ 0.         -2.         11.         31.        ]
#  [ 0.          0.         21.5        64.5       ]]
# array([-1.,  1.,  3.])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Ab = [
    [1, -1, 3, 2],
    [3, -3, 1, -1],
    [1, 1, 0, 3]
]

eliminacion_gaussiana2(Ab)
# Out:
# Intercambiando filas 1 y 2
# array([1.1875, 1.8125, 0.875 ])

# %%
Ab = [
    [2, -1.5, 3, 1],
    [-1, 0, 2, 3],
    [4, -4.5, 5, 1]
]

eliminacion_gaussiana2(Ab)
# Out:
# Intercambiando filas 0 y 1
# array([-1., -0.,  1.])

# %%
A = [
    [2, 0, 0, 0, 3],
    [1, 1.5, 0, 0, 4.5],
    [0, -3, 0.5, 0, -6.6],
    [2, -2, 1, 1, 0.8]
]

eliminacion_gaussiana2(A)
# Out:
# Intercambiando filas 0 y 1
# array([ 1.5,  2. , -1.2,  3. ])

# %%
A = [
    [1, 1, 0, 1, 2],
    [2, 1, -1, 1, 1],
    [4, -1, -2, 2, 0],
    [3, -1, -1, 2, -3]
]

eliminacion_gaussiana2(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 8
#       1 A = [
#       2     [1, 1, 0, 1, 2],
#       3     [2, 1, -1, 1, 1],
#       4     [4, -1, -2, 2, 0],
#       5     [3, -1, -1, 2, -3]
#       6 ]
# ----> 8 eliminacion_gaussiana2(A)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:285, in eliminacion_gaussiana2(A)
#     281         A[j, i:] = A[j, i:] - m * A[i, i:]
#     284 if A[n - 1, n - 1] == 0:
# --> 285     raise ValueError("No existe solución única.")
#     287     print(f"\n{A}")
#     288 # --- Sustitución hacia atrás
#
# ValueError: No existe solución única.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ejercicio a \n")

A = np.array([[1/4, 1/5, 1/6, 9],
              [1/3, 1/4, 1/5, 8],
              [1/2, 1, 2, 8]], dtype=np.float32)
eliminacion_gaussiana3(A)
# Out:
# Ejercicio a
# array([-227.07666,  476.92264, -177.69217], dtype=float32)

# %%
print("Ejercicio b \n")
A = np.array([[3.333, 15920, 10.333, 15913],
              [2.222, 16.71, 9.612, 28.544],
              [1.5611, 5.1791, 1.6852, 8.4254]], dtype=np.float32)

eliminacion_gaussiana3(A)
# Out:
# Ejercicio b
#
# Intercambiando filas 0 y 2
# array([1.0024955, 0.9987004, 1.0016824], dtype=float32)

# %%
print("Ejercicio c \n")
A = np.array([[1, 1/2, 1/3, 1/4, 1/6],
              [1/2, 1/3, 1/4, 1/5, 1/7],
              [1/3, 1/4, 1/5, 1/6, 1/8],
              [1/4, 1/5, 1/6, 1/7, 1/9]], dtype=np.float32)

eliminacion_gaussiana3(A)
# Out:
# Ejercicio c
#
# Intercambiando filas 0 y 3
# Intercambiando filas 1 y 2
# array([-0.03174075,  0.5951853 , -2.3808312 ,  2.7777011 ], dtype=float32)

# %%
print("Ejercicio d \n")
A = np.array([[2, 1, -1, 1, -3, 7],
              [1, 0, 2, -1, 1, 2],
              [0, -2, -1, 1, -1, -5],
              [3, 1, -4, 0, 5, 6],
              [1, -1, -1, -1, 1, -3]], dtype=np.float32)

eliminacion_gaussiana3(A)
# Out:
# Ejercicio d
#
# Intercambiando filas 0 y 1
# Intercambiando filas 2 y 3
# Intercambiando filas 3 y 4
# array([1.8830411 , 2.807017  , 0.73099416, 1.4385967 , 0.09356727],
#       dtype=float32)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Literal c \n")
A = [
    [1, -1, 2],
    [-1, 2, -2],
    [2, 1, 1]
]

b = [-2, 3, 2]

np.linalg.solve(A, b)
# Out:
# Literal c
# array([ 1.,  1., -1.])

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# <!--  -->
#
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %%
A = [
    [1, 2, 0, 3],
    [1, 0, 2, 2],
    [0, 0, 1, 1]
]

x = [1000, 500, 350, 400]

np.matmul(A, x)
# Out:
# array([3200, 2500,  750])

# %%
A = [
    [1, 2, 0, 3],
    [1, 0, 2, 2],
    [0, 0, 1, 1]
]

b = [3500, 2700, 900]

np.linalg.solve(A, b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[41], line 9
#       1 A = [
#       2     [1, 2, 0, 3],
#       3     [1, 0, 2, 2],
#       4     [0, 0, 1, 1]
#       5 ]
#       7 b = [3500, 2700, 900]
# ----> 9 np.linalg.solve(A, b)
#
# File c:\Users\luis3\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\linalg\_linalg.py:399, in solve(a, b)
#     397 a, _ = _makearray(a)
#     398 _assert_stacked_2d(a)
# --> 399 _assert_stacked_square(a)
#     400 b, wrap = _makearray(b)
#     401 t, result_t = _commonType(a, b)
#
# File c:\Users\luis3\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\linalg\_linalg.py:202, in _assert_stacked_square(*arrays)
#     200 m, n = a.shape[-2:]
#     201 if m != n:
# --> 202     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
A = [
    [2, 0, 3],
    [0, 2, 2],
    [0, 1, 1]
]

b = [3500, 2700, 900]

np.linalg.solve(A, b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[13], line 9
#       1 A = [
#       2     [2, 0, 3],
#       3     [0, 2, 2],
#       4     [0, 1, 1]
#       5 ]
#       7 b = [3500, 2700, 900]
# ----> 9 np.linalg.solve(A, b)
#
# File c:\Users\luis3\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\linalg\_linalg.py:413, in solve(a, b)
#     410 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     411 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     412               over='ignore', divide='ignore', under='ignore'):
# --> 413     r = gufunc(a, b, signature=signature)
#     415 return wrap(r.astype(result_t, copy=False))
#
# File c:\Users\luis3\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\linalg\_linalg.py:104, in _raise_linalgerror_singular(err, flag)
#     103 def _raise_linalgerror_singular(err, flag):
# ...

# %%
A = [
    [1, 0, 3],
    [1, 2, 2],
    [0, 1, 1]
]

b = [3500, 2700, 900]

np.linalg.solve(A, b)
# Out:
# array([900.        ,  33.33333333, 866.66666667])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ejercicio a \n")
A = np.array([[1/4, 1/5, 1/6, 9.0],
              [1/3, 1/4, 1/5, 8],
              [1/2, 1, 2, 8]], dtype=np.float32)
    
eliminacion_gauss_jordan(A)
# Out:
# Ejercicio a
#
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[ 1.          0.80000001  0.66666669 36.        ]
#  [ 0.33333334  0.25        0.2         8.        ]
#  [ 0.5         1.          2.          8.        ]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.00000000e+00  8.00000012e-01  6.66666687e-01  3.60000000e+01]
#  [ 0.00000000e+00 -1.66666786e-02 -2.22222325e-02 -4.00000036e+00]
#  [ 5.00000000e-01  1.00000000e+00  2.00000000e+00  8.00000000e+00]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.00000000e+00  8.00000012e-01  6.66666687e-01  3.60000000e+01]
#  [ 0.00000000e+00 -1.66666786e-02 -2.22222325e-02 -4.00000036e+00]
#  [ 0.00000000e+00  5.99999994e-01  1.66666666e+00 -1.00000000e+01]]
# --------------------------------------------------
# Paso 2: Normalizar fila 2 (hacer pivote igual a 1):
# ...

# %%
print("Ejercicio b \n")
A = np.array([[3.333, 15920, 10.333, 15913],
              [2.222, 16.71, 9.612, 28.544],
              [1.5611, 5.1791, 1.6852, 8.4254]], dtype=np.float32)

eliminacion_gauss_jordan(A)
# Out:
# Ejercicio b
#
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[1.00000000e+00 4.77647773e+03 3.10021013e+00 4.77437752e+03]
#  [2.22199988e+00 1.67099991e+01 9.61200047e+00 2.85440006e+01]
#  [1.56110001e+00 5.17910004e+00 1.68519998e+00 8.42539978e+00]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.00000000e+00  4.77647773e+03  3.10021013e+00  4.77437752e+03]
#  [ 0.00000000e+00 -1.05966230e+04  2.72333392e+00 -1.05801223e+04]
#  [ 1.56110001e+00  5.17910004e+00  1.68519998e+00  8.42539978e+00]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.00000000e+00  4.77647773e+03  3.10021013e+00  4.77437752e+03]
#  [ 0.00000000e+00 -1.05966230e+04  2.72333392e+00 -1.05801223e+04]
#  [ 0.00000000e+00 -7.45138031e+03 -3.15453807e+00 -7.44485537e+03]]
# --------------------------------------------------
# ...

# %%
print("Ejercicio c \n")
A = np.array([[1, 1/2, 1/3, 1/4, 1/6],
              [1/2, 1/3, 1/4, 1/5, 1/7],
              [1/3, 1/4, 1/5, 1/6, 1/8],
              [1/4, 1/5, 1/6, 1/7, 1/9]], dtype=np.float32)

eliminacion_gauss_jordan(A)
# Out:
# Ejercicio c
#
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.5        0.33333334 0.25       0.2        0.14285715]
#  [0.33333334 0.25       0.2        0.16666667 0.125     ]
#  [0.25       0.2        0.16666667 0.14285715 0.11111111]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.         0.08333334 0.08333333 0.075      0.05952381]
#  [0.33333334 0.25       0.2        0.16666667 0.125     ]
#  [0.25       0.2        0.16666667 0.14285715 0.11111111]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[1.         0.5        0.33333334 0.25       0.16666667]
#  [0.         0.08333334 0.08333333 0.075      0.05952381]
#  [0.         0.08333333 0.08888889 0.08333334 0.06944444]
# ...

# %%
print("Ejercicio d \n")
A = np.array([[2, 1, -1, 1, -3, 7],
              [1, 0, 2, -1, 1, 2],
              [0, -2, -1, 1, -1, -5],
              [3, 1, -4, 0, 5, 6],
              [1, -1, -1, -1, 1, -3]], dtype=np.float32)

eliminacion_gauss_jordan(A)
# Out:
# Ejercicio d
#
# Paso 1: Normalizar fila 1 (hacer pivote igual a 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 1.   0.   2.  -1.   1.   2. ]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.2: Hacer cero el elemento en la posición (2, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.3: Hacer cero el elemento en la posición (3, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 3.   1.  -4.   0.   5.   6. ]
#  [ 1.  -1.  -1.  -1.   1.  -3. ]]
# --------------------------------------------------
# Paso 1.4: Hacer cero el elemento en la posición (4, 1):
# [[ 1.   0.5 -0.5  0.5 -1.5  3.5]
# ...
