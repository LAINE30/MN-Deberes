# %% [markdown]
# # Escuela Politécnica Nacional
# ### [Tarea 12] Ejercicios Unidad 05-A | ODE Método de Euler
# ### Solo resolver ejercicios 3, 4 y 5.
# **Nombre:** Mateo Coronado
#
# **Fecha:** 06/02/2025
#
# **Materia:** Métodos Numéricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %load_ext autoreload
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio A

# %%
def ODE_euler(a: float, b: float, f, y_t0: float, N: int):
    h = (b - a) / N  # tamaño del paso
    t_values = [a + i*h for i in range(N+1)]  # valores de t
    y_values = [y_t0]  # valores de y
    y = y_t0
    
    for i in range(1, N+1):
        y = y + h * f(t_values[i-1], y)  # Método de Euler
        y_values.append(y)
        
    # Imprimir la tabla de resultados
    print("Tabla de resultados (t_i, y(t_i)) para el Literal a)")
    print("-----------------------------------------------------")
    print(f"{'t_i':<10} {'y(t_i)'}")
    for t, y in zip(t_values, y_values):
        print(f"{t:<10.2f} {y:.6f}")
        
    return y_values, t_values, h

# Parámetros para el problema a
a = 1
b = 2
y_t0_a = 1
h_a = 0.1
N_a = int((b - a) / h_a)

# Definir la función f para el problema a
def f_a(t, y):
    return y / t - (y / t)**2

ys_a, ts_a, h_a = ODE_euler(a=a, b=b, f=f_a, y_t0=y_t0_a, N=N_a)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(ts_a, ys_a, marker='o', linestyle='-', color='c', label='Aproximación de Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Aproximación de Euler para el Literal a')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Tabla de resultados (t_i, y(t_i)) para el Literal a)
# -----------------------------------------------------
# t_i        y(t_i)
# 1.00       1.000000
# 1.10       1.000000
# 1.20       1.008264
# 1.30       1.021689
# 1.40       1.038515
# 1.50       1.057668
# 1.60       1.078461
# 1.70       1.100432
# 1.80       1.123262
# 1.90       1.146724
# 2.00       1.170652

# %% [markdown]
# ### Ejercicios B

# %%
def ODE_euler(a: float, b: float, f, y_t0: float, N: int):
    h = (b - a) / N  # tamaño del paso
    t_values = [a + i*h for i in range(N+1)]  # valores de t
    y_values = [y_t0]  # valores de y
    y = y_t0
    
    for i in range(1, N+1):
        y = y + h * f(t_values[i-1], y)  # Método de Euler
        y_values.append(y)
        
    # Imprimir la tabla de resultados
    print("Tabla de resultados (t_i, y(t_i)) para el Literal b)")
    print("-----------------------------------------------------")
    print(f"{'t_i':<10} {'y(t_i)'}")
    for t, y in zip(t_values, y_values):
        print(f"{t:<10.2f} {y:.6f}")
        
    return y_values, t_values, h

# Definir la función f para el problema b
def f_b(t, y):
    return 1 + y / t + (y / t)**2

# Parámetros para el problema b
a_b = 1
b_b = 3
y_t0_b = 0
h_b = 0.2
N_b = int((b_b - a_b) / h_b)

ys_b, ts_b, h_b = ODE_euler(a=a_b, b=b_b, f=f_b, y_t0=y_t0_b, N=N_b)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(ts_b, ys_b, marker='o', linestyle='-', color='m', label='Aproximación de Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Aproximación de Euler para el Literal b')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Tabla de resultados (t_i, y(t_i)) para el Literal b)
# -----------------------------------------------------
# t_i        y(t_i)
# 1.00       0.000000
# 1.20       0.200000
# 1.40       0.438889
# 1.60       0.721243
# 1.80       1.052038
# 2.00       1.437251
# 2.20       1.884261
# 2.40       2.402270
# 2.60       3.002837
# 2.80       3.700601
# 3.00       4.514277

# %% [markdown]
# ### Ejercicio C

# %%
def ODE_euler(a: float, b: float, f, y_t0: float, N: int):
    h = (b - a) / N  # tamaño del paso
    t_values = [a + i*h for i in range(N+1)]  # valores de t
    y_values = [y_t0]  # valores de y
    y = y_t0
    
    for i in range(1, N+1):
        y = y + h * f(t_values[i-1], y)  # Método de Euler
        y_values.append(y)
        
    # Imprimir la tabla de resultados
    print("Tabla de resultados (t_i, y(t_i)) para el Literal c)")
    print("-----------------------------------------------------")
    print(f"{'t_i':<10} {'y(t_i)'}")
    for t, y in zip(t_values, y_values):
        print(f"{t:<10.2f} {y:.6f}")
        
    return y_values, t_values, h

# Definir la función f para el problema c
def f_c(t, y):
    return -(y + 1) * (y + 3)

# Parámetros para el problema c
a_c = 0
b_c = 2
y_t0_c = -2
h_c = 0.2
N_c = int((b_c - a_c) / h_c)

ys_c, ts_c, h_c = ODE_euler(a=a_c, b=b_c, f=f_c, y_t0=y_t0_c, N=N_c)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(ts_c, ys_c, marker='o', linestyle='-', color='g', label='Aproximación de Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Aproximación de Euler para el Literal c')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Tabla de resultados (t_i, y(t_i)) para el Literal c)
# -----------------------------------------------------
# t_i        y(t_i)
# 0.00       -2.000000
# 0.20       -1.800000
# 0.40       -1.608000
# 0.60       -1.438733
# 0.80       -1.301737
# 1.00       -1.199251
# 1.20       -1.127491
# 1.40       -1.079745
# 1.60       -1.049119
# 1.80       -1.029954
# 2.00       -1.018152

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ejercicio c \n")
Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio c
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 print("Ejercicio c \n")
#       2 Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:43, in eliminacion_gaussiana(A)
#      41     logging.debug("Convirtiendo A a numpy array.")
#      42     A = np.array(A)
# ---> 43 assert A.shape[0] == A.shape[1] - 1, "La matriz A debe ser de tamaño n-by-(n+1)."
#      44 n = A.shape[0]
#      46 for i in range(0, n - 1):  # loop por columna
#      47
#      48     # --- encontrar pivote
#
# AssertionError: La matriz A debe ser de tamaño n-by-(n+1).
