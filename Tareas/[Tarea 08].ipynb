# %% [markdown]
# # Escuela Politécnica Nacional
# ### [Tarea 08] Ejercicios Unidad 03-C mínimos cuadrados
# **Nombre:** Mateo Coronado
#
# **Fecha:** 03/01/2025
#
# **Materia:** Métodos Numéricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a. Construya el polinomio por mínimos cuadrados de grado I y calcule el error.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Definir los puntos
xs = np.array([4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1])
ys = np.array([102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72])

# Ajustar un polinomio de grado 1 (lineal) usando el método de mínimos cuadrados
i = 1
for i in range(1, 4):
    print("Iteración: ", i)
    
    # Ajustar un polinomio de grado 1 (lineal) usando el método de mínimos cuadrados
    coefficients = np.polyfit(xs, ys, i)
    polynomial = np.poly1d(coefficients)

    # Calcular los valores ajustados
    ys_fit = polynomial(xs)

    # Calcular el error cuadrático medio
    error = np.mean((ys - ys_fit) ** 2)

    print("Coeficientes del polinomio:", coefficients)
    print("Error cuadrático medio:", error)

    plt.scatter(xs, ys, color='blue', label='Datos originales')
    plt.plot(xs, ys_fit, color='red', label='Ajuste lineal')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim(3, 8)
    plt.ylim(100, 350)
    plt.title('Ajuste lineal por mínimos cuadrados')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    i += 1


# Datos de ejemplo
# Modelo de la for ma b * e^(a * x)
def modelo_exponencial(xs, a, b):
    return b * np.exp(a * xs)

# Ajuste del modelo
parametros_optimos, _ = curve_fit(modelo_exponencial, xs, ys)
a_opt, b_opt = parametros_optimos

# Predicciones del modelo
y_pred = modelo_exponencial(xs, a_opt, b_opt)

# Cálculo del error cuadrático medio (MSE)
mse = np.mean((ys - y_pred)**2)

# Resultados
print(f"Parámetros óptimos: a = {a_opt:.4f}, b = {b_opt:.4f}")
print(f"Error cuadrático medio (MSE): {mse:.4f}")

# Visualización
plt.scatter(xs, ys, label="Datos originales", color="red")
plt.plot(xs, y_pred, label=f"Ajuste: {b_opt:.2f}e^({a_opt:.2f}x)", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Ajuste por mínimos cuadrados exponencial")
plt.show()


def modelo_exponente(xs, a, b):
    return b * xs**(a)

# Ajuste del modelo
parametros_optimos, _ = curve_fit(modelo_exponente, xs, ys)
a_opt, b_opt = parametros_optimos

# Predicciones del modelo
y_pred = modelo_exponente(xs, a_opt, b_opt)

# Cálculo del error cuadrático medio (MSE)
mse = np.mean((ys - y_pred)**2)

# Resultados
print(f"Parámetros óptimos: a = {a_opt:.4f}, b = {b_opt:.4f}")
print(f"Error cuadrático medio (MSE): {mse:.4f}")

# Visualización
plt.scatter(xs, ys, label="Datos originales", color="red")
plt.plot(xs, y_pred, label=f"Ajuste: {b_opt:.2f}e^({a_opt:.2f}x)", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Ajuste por mínimos cuadrados elevado")
plt.show()
# Out:
# Iteración:  1
# Coeficientes del polinomio: [  71.61024372 -191.57241853]
# Error cuadrático medio: 105.88388862638904
# Iteración:  2
# Coeficientes del polinomio: [  8.21707232 -19.30860379  51.00078939]
# Error cuadrático medio: 55.16562001170232
# Iteración:  3
# Coeficientes del polinomio: [  -2.60683872   51.56095694 -254.87478338  469.16326528]
# Error cuadrático medio: 51.83830647403006
# Parámetros óptimos: a = 0.3549, b = 26.8408
# Error cuadrático medio (MSE): 74.3622
# Parámetros óptimos: a = 2.0152, b = 6.2840
# Error cuadrático medio (MSE): 57.2582

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Definir los puntos
xs = np.array([0.2,0.3,0.6,0.9,1.1,1.3,1.4,1.6])
ys = np.array([0.050446,0.098426,0.33277,0.72660,1.0972,1.5697,1.8487,2.5015])

# Ajustar un polinomio de grado 1 (lineal) usando el método de mínimos cuadrados
i = 1
for i in range(1, 4):
    print("Iteración: ", i)
    
    # Ajustar un polinomio de grado 1 (lineal) usando el método de mínimos cuadrados
    coefficients = np.polyfit(xs, ys, i)
    polynomial = np.poly1d(coefficients)

    # Calcular los valores ajustados
    ys_fit = polynomial(xs)

    # Calcular el error cuadrático medio
    error = np.mean((ys - ys_fit) ** 2)

    print("Coeficientes del polinomio:", coefficients)
    print("Error cuadrático medio:", error)

    plt.scatter(xs, ys, color='blue', label='Datos originales')
    plt.plot(xs, ys_fit, color='red', label='Ajuste lineal')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Ajuste lineal por mínimos cuadrados')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    i += 1


# Datos de ejemplo
# Modelo de la for ma b * e^(a * x)
def modelo_exponencial(xs, a, b):
    return b * np.exp(a * xs)

# Ajuste del modelo
parametros_optimos, _ = curve_fit(modelo_exponencial, xs, ys)
a_opt, b_opt = parametros_optimos

# Predicciones del modelo
y_pred = modelo_exponencial(xs, a_opt, b_opt)

# Cálculo del error cuadrático medio (MSE)
mse = np.mean((ys - y_pred)**2)

# Resultados
print(f"Parámetros óptimos: a = {a_opt:.4f}, b = {b_opt:.4f}")
print(f"Error cuadrático medio (MSE): {mse:.4f}")

# Visualización
plt.scatter(xs, ys, label="Datos originales", color="red")
plt.plot(xs, y_pred, label=f"Ajuste: {b_opt:.2f}e^({a_opt:.2f}x)", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Ajuste por mínimos cuadrados")
plt.show()


def modelo_exponente(xs, a, b):
    return b * xs**(a)

# Ajuste del modelo
parametros_optimos, _ = curve_fit(modelo_exponente, xs, ys)
a_opt, b_opt = parametros_optimos

# Predicciones del modelo
y_pred = modelo_exponente(xs, a_opt, b_opt)

# Cálculo del error cuadrático medio (MSE)
mse = np.mean((ys - y_pred)**2)

# Resultados
print(f"Parámetros óptimos: a = {a_opt:.4f}, b = {b_opt:.4f}")
print(f"Error cuadrático medio (MSE): {mse:.4f}")

# Visualización
plt.scatter(xs, ys, label="Datos originales", color="red")
plt.plot(xs, y_pred, label=f"Ajuste: {b_opt:.2f}e^({a_opt:.2f}x)", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Ajuste por mínimos cuadrados")
plt.show()
# Out:
# Iteración:  1
# Coeficientes del polinomio: [ 1.66554008 -0.51245682]
# Error cuadrático medio: 0.041948731969935996
# Iteración:  2
# Coeficientes del polinomio: [ 1.12942387 -0.31140346  0.08514393]
# Error cuadrático medio: 0.0003024893661783383
# Iteración:  3
# Coeficientes del polinomio: [ 0.2662081   0.40293221  0.24838578 -0.0184014 ]
# Error cuadrático medio: 6.343339444533196e-07
# Parámetros óptimos: a = 1.8583, b = 0.1326
# Error cuadrático medio (MSE): 0.0085
# Parámetros óptimos: a = 2.1428, b = 0.9055
# Error cuadrático medio (MSE): 0.0004

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Ajustar un polinomio de grado 3 usando el método de mínimos cuadrados

xs = np.array([28, 25, 28, 27, 28, 33, 28, 29, 23, 27, 29, 28, 27, 29, 21, 28, 28, 26, 30, 24])  # Puntuación ACT
ys = np.array([3.84, 3.21, 3.23, 3.63, 3.75, 3.20, 3.41, 3.38, 3.53, 2.03, 3.75, 3.65, 3.87, 3.75, 1.66, 3.12, 2.96, 2.92, 3.10, 2.81])  # Promedio de puntos

grado = 1
coeficientes = np.polyfit(xs, ys, grado)
polinomio = np.poly1d(coeficientes)

# Calcular los valores ajustados
ys_ajustados = polinomio(xs)

# Calcular el error cuadrático medio
error_cuadratico_medio = np.mean((ys - ys_ajustados) ** 2)

print("Coeficientes del polinomio:", coeficientes)
print("Error cuadrático medio:", error_cuadratico_medio)

# Graficar los datos originales y el ajuste polinómico
plt.scatter(xs, ys, color='blue', label='Datos originales')
plt.plot(xs, ys_ajustados, color='red', label='Ajuste polinómico')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste polinómico por mínimos cuadrados')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Coeficientes del polinomio: [0.10085803 0.48657566]
# Error cuadrático medio: 0.2524352808112325

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Ajustar un polinomio de grado 3 usando el método de mínimos cuadrados

xs = np.array([4800, 3700, 3400, 2800, 1900])  # Puntuación ACT
ys = np.array([3.1, 4.0, 5.2, 6.4, 9.6])  # Promedio de puntos

grado = 1
for i in range(1,3):
    coeficientes = np.polyfit(xs, ys, i)
    polinomio = np.poly1d(coeficientes)

    # Calcular los valores ajustados
    ys_ajustados = polinomio(xs)

    # Calcular el error cuadrático medio
    error_cuadratico_medio = np.mean((ys - ys_ajustados) ** 2)

    print("Coeficientes del polinomio:", coeficientes)
    print("Error cuadrático medio:", error_cuadratico_medio)

    # Graficar los datos originales y el ajuste polinómico
    plt.scatter(xs, ys, color='blue', label='Datos originales')
    plt.plot(xs, ys_ajustados, color='red', label='Ajuste polinómico')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Ajuste polinómico por mínimos cuadrados')
    plt.legend()
    plt.grid(True)
    plt.show()


# Calcular los valores ajustados
ys_ajustados = polinomio(xs)

# Calcular el error cuadrático medio
error_cuadratico_medio = np.mean((ys - ys_ajustados) ** 2)

print("Coeficientes del polinomio:", coeficientes)
print("Error cuadrático medio:", error_cuadratico_medio)

# Graficar los datos originales y el ajuste polinómico
plt.scatter(xs, ys, color='blue', label='Datos originales')
plt.plot(xs, ys_ajustados, color='red', label='Ajuste polinómico')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste polinómico por mínimos cuadrados')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Coeficientes del polinomio: [-2.25496975e-03  1.31464996e+01]
# Error cuadrático medio: 0.411827139152982
# Coeficientes del polinomio: [ 6.34947528e-07 -6.51125846e-03  1.96910250e+01]
# Error cuadrático medio: 0.03644901419615019
# Coeficientes del polinomio: [ 6.34947528e-07 -6.51125846e-03  1.96910250e+01]
# Error cuadrático medio: 0.03644901419615019
