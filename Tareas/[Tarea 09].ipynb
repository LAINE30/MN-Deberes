# %% [markdown]
# # Escuela Politécnica Nacional
# ### [Tarea 09] Ejercicios Unidad 04-A-B | Eliminación gaussiana vs Gauss-Jordan
# **Nombre:** Mateo Coronado
#
# **Fecha:** 03/01/2025
#
# **Materia:** Métodos Numéricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana2
from src import eliminacion_gaussiana3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 4
#       2 from src import eliminacion_gaussiana
#       3 from src import eliminacion_gaussiana2
# ----> 4 from src import eliminacion_gaussiana3
#
# ImportError: cannot import name 'eliminacion_gaussiana3' from 'src' (c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\__init__.py)

# %%
# %autoreload 2
from src import eliminacion_gaussiana
from src import eliminacion_gaussiana2
print("Ejercicio a \n")
Ab = [[1, 2, 0], [1, -1, 0]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio a
#
# [01-07 20:37:29][INFO]
# [[ 1  2  0]
#  [ 0 -3  0]]
# array([ 0., -0.])

# %%
print("Ejercicio b \n")
Ab = [[1, 2, 3], [-2, -4, 6]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio b
#
# [01-07 20:22:56][INFO]
# [[ 1  2  3]
#  [ 0  0 12]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 print("Ejercicio b \n")
#       2 Ab = [[1, 2, 3], [-2, -4, 6]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:82, in eliminacion_gaussiana(A)
#      79     logging.info(f"\n{A}")
#      81 if A[n - 1, n - 1] == 0:
# ---> 82     raise ValueError("No existe solución única.")
#      84     print(f"\n{A}")
#      85 # --- Sustitución hacia atrás
#
# ValueError: No existe solución única.

# %% [markdown]
# El ejercicio b tiene la ecuacion de la forma 0=12 por lo cual no tiene solución

# %%
print("Ejercicio c \n")
Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio c
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 print("Ejercicio c \n")
#       2 Ab = [[2, 1, -1], [1, 1, 2], [1, -3, 5]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:43, in eliminacion_gaussiana(A)
#      41     logging.debug("Convirtiendo A a numpy array.")
#      42     A = np.array(A)
# ---> 43 assert A.shape[0] == A.shape[1] - 1, "La matriz A debe ser de tamaño n-by-(n+1)."
#      44 n = A.shape[0]
#      46 for i in range(0, n - 1):  # loop por columna
#      47
#      48     # --- encontrar pivote
#
# AssertionError: La matriz A debe ser de tamaño n-by-(n+1).

# %% [markdown]
# Tiene soluciones infinitas

# %%
print("Ejercicio d \n")
Ab = [[2, 1, 1, 1], [2, 4, -1, -1]]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio d
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 print("Ejercicio d \n")
#       2 Ab = [[2, 1, 1, 1], [2, 4, -1, -1]]
# ----> 4 eliminacion_gaussiana(Ab)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:43, in eliminacion_gaussiana(A)
#      41     logging.debug("Convirtiendo A a numpy array.")
#      42     A = np.array(A)
# ---> 43 assert A.shape[0] == A.shape[1] - 1, "La matriz A debe ser de tamaño n-by-(n+1)."
#      44 n = A.shape[0]
#      46 for i in range(0, n - 1):  # loop por columna
#      47
#      48     # --- encontrar pivote
#
# AssertionError: La matriz A debe ser de tamaño n-by-(n+1).

# %% [markdown]
# Tiene soluciones infinitas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ejercicio a \n")
Ab = [[-1.0, 4, 1, 8], [5/3, 2/3, -2/3, 1.0], [2, 1, 4, 11.0]]
Ab = [[round(elem, 2) for elem in row] for row in Ab]

eliminacion_gaussiana(Ab)
# Out:
# Ejercicio a
#
# [01-07 20:29:44][INFO]
# [[-1.    4.    1.    8.  ]
#  [ 0.    7.35  1.   14.36]
#  [ 0.    9.    6.   27.  ]]
# [01-07 20:29:44][INFO]
# [[-1.          4.          1.          8.        ]
#  [ 0.          7.35        1.         14.36      ]
#  [ 0.          0.          4.7755102   9.41632653]]
# array([0.71367521, 1.68547009, 1.97179487])

# %%
print("Ejercicio b \n")
Ab = [[4, 2, -1, -5], [1/9, 1/9, -1/3, -1.0], [1, 4, 2, 9]]


eliminacion_gaussiana(Ab)
# Out:
# Ejercicio b
#
# [01-07 20:29:14][INFO]
# [[ 0.11111111  0.11111111 -0.33333333 -1.        ]
#  [ 0.         -2.         11.         31.        ]
#  [ 0.          3.          5.         18.        ]]
# [01-07 20:29:14][INFO]
# [[ 0.11111111  0.11111111 -0.33333333 -1.        ]
#  [ 0.         -2.         11.         31.        ]
#  [ 0.          0.         21.5        64.5       ]]
# array([-1.,  1.,  3.])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Ab = [
    [1, -1, 3, 2],
    [3, -3, 1, -1],
    [1, 1, 0, 3]
]

eliminacion_gaussiana2(Ab)
# Out:
# Intercambiando filas 1 y 2
# array([1.1875, 1.8125, 0.875 ])

# %%
Ab = [
    [2, -1.5, 3, 1],
    [-1, 0, 2, 3],
    [4, -4.5, 5, 1]
]

eliminacion_gaussiana2(Ab)
# Out:
# Intercambiando filas 0 y 1
# array([-1., -0.,  1.])

# %%
A = [
    [2, 0, 0, 0, 3],
    [1, 1.5, 0, 0, 4.5],
    [0, -3, 0.5, 0, -6.6],
    [2, -2, 1, 1, 0.8]
]

eliminacion_gaussiana2(A)
# Out:
# Intercambiando filas 0 y 1
# array([ 1.5,  2. , -1.2,  3. ])

# %%
A = [
    [1, 1, 0, 1, 2],
    [2, 1, -1, 1, 1],
    [4, -1, -2, 2, 0],
    [3, -1, -1, 2, -3]
]

eliminacion_gaussiana2(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 8
#       1 A = [
#       2     [1, 1, 0, 1, 2],
#       3     [2, 1, -1, 1, 1],
#       4     [4, -1, -2, 2, 0],
#       5     [3, -1, -1, 2, -3]
#       6 ]
# ----> 8 eliminacion_gaussiana2(A)
#
# File c:\Users\luis3\OneDrive - Escuela Politécnica Nacional\Universidad\Cuarto Semestre\METODOS NUMERICOS\src\linear_sist_methods.py:285, in eliminacion_gaussiana2(A)
#     281         A[j, i:] = A[j, i:] - m * A[i, i:]
#     284 if A[n - 1, n - 1] == 0:
# --> 285     raise ValueError("No existe solución única.")
#     287     print(f"\n{A}")
#     288 # --- Sustitución hacia atrás
#
# ValueError: No existe solución única.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 1 3 1.5 0.75 -0.25
# 0 2 0.75 0.0 0.25
# 0.75*x + 0.25*(x - 1)**3 + 1.25
# 1.5*x - 0.25*(x - 2)**3 + 0.75*(x - 2)**2
# ______
# 0.25*x**3 - 0.75*x**2 + 1.5*x + 1.0
# -0.25*x**3 + 2.25*x**2 - 4.5*x + 5.0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Out:
# 2 5 1.0 -6.0 2.0
# 1 1 4.0 3.0 -3.0
# 0 -1 1.0 0.0 1.0
# 1.0*x**3 + 1.0*x - 1
# 4.0*x - 3.0*(x - 1)**3 + 3.0*(x - 1)**2 - 3.0
# 1.0*x + 2.0*(x - 2)**3 - 6.0*(x - 2)**2 + 3.0
# ______
# 1.0*x**3 + 1.0*x - 1
# -3.0*x**3 + 12.0*x**2 - 11.0*x + 3.0
# 2.0*x**3 - 18.0*x**2 + 49.0*x - 37.0

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
#
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
